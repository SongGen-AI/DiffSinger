# %% [markdown]
# # **(Optional)**

# %%
#@markdown # Drop Speakers from Model (Optional)
#@markdown ___
#@markdown <font size="-1.5"> Use this to drop speakers from your model for distribution. You will need to do it for both acoustic and variance models.

drop_model_path = '' #@param {type: "string"}
#@markdown <font size="-1.5"> Type the ID of speakers you'd like to KEEP separated by commas. Ex: "0,3,4" <br>
#@markdown <font size="-1.5"> Note: You can find the ID of speakers in the model by opening the ```spk_map.json``` file in the model folder.<br>
#@markdown <font size="-1.5"> If you see ```{"natural": 0, "power": 1, "silly": 2}``` but only want to keep "natural" and "power", type ```0,1``` below.
retain_speakers = '' #@param {type: "string"}
#@markdown <font size="-1.5"> If you don't know what this means, don't change it.
fill_embed = 'zeros' #@param ['zeros', 'random', 'mean', 'cyclic']

drop_out_path = drop_model_path[:-5] + '_spk-dropped.ckpt'

# !python /workspace/content/DiffSinger/scripts/drop_spk.py {drop_model_path} {drop_out_path} --retain {retain_speakers} --fill {fill_embed}

# %% [markdown]
# # **Export ONNX**

# %%
# Export ONNX
# %cd /workspace/content
# from IPython.display import clear_output
# clear_output()
import os
import zipfile
import shutil

#move this here so users doesnt have to wait for this to install for training
print("installing dependencies for onnx conversion...")
# !pip install torch==1.13.0 torchvision==0.14.0 torchaudio==0.13.0 -q -q -q 2>/dev/null

# to counter IF the user is to re-run this cell <3
if os.path.exists("/workspace/content/OU_compatible_files"):
    shutil.rmtree("/workspace/content/OU_compatible_files")
    os.remove("/workspace/content/jpn_dict.txt")
else:
    pass

#@markdown <font size="-1.5"> select this if you don't want to see the onnx converter's output
no_output = False # @param {type:"boolean"}

#@markdown <font size="-1.5"> path to your **ACOUSTIC CHECKPOINT** (leave blank if you don't have any): automatically use latest checkpoint that is in the same folder
acoustic_checkpoint_path = "/workspace/content/DiffSinger/MyModel_Acoustic/model_ckpt_steps_54000.ckpt" #@param{type:"string'}
acoustic_folder_name = os.path.basename(os.path.dirname(acoustic_checkpoint_path)) + "_acoustic"
acoustic_folder_path = os.path.dirname(acoustic_checkpoint_path)
print("acoustic_folder_path", acoustic_folder_path)

#@markdown <font size="-1.5"> path to your **VARIANCE CHECKPOINT** (leave blank if you don't have any): automatically use latest checkpoint that is in the same folder
variance_checkpoint_path = "/workspace/content/DiffSinger/MyModel_Variance/model_ckpt_steps_64000.ckpt" #@param{type:"string'}
variance_folder_name = os.path.basename(os.path.dirname(variance_checkpoint_path)) + "_variance"
variance_folder_path = os.path.dirname(variance_checkpoint_path)

#@markdown <font size="-1.5"> path to where you want to save your ONNX files (it will create a folder named "onnx" in this path)
exp_folder = "/workspace/content/DiffSinger/MyModel_export" #@param{type:"string"}

acoustic_onnx_exp = exp_folder + "/onnx/acoustic"
variance_onnx_exp = exp_folder + "/onnx/variance"

if not acoustic_checkpoint_path:
    print("\n")
    print("acoustic ckeckpoint path not specified, not exporting acoustic ONNX...")
else:
    print("\n")
    print("converting acoustic to onnx...")
    #cp stuff cus apparently exporter doesnt work without it
    # !cp {acoustic_folder_path}/config.yaml -r /workspace/content/DiffSinger/checkpoints/{acoustic_folder_name}
    search_text = "        args_work_dir = os.path.join("
    replacement = f"        args_work_dir = '{acoustic_folder_path}'"
    with open("/workspace/content/DiffSinger/utils/hparams.py", "r") as file:
        lines = file.readlines()
    for i, line in enumerate(lines):
        if search_text in line:
            lines[i] = replacement + "\n"
            break
    with open("/workspace/content/DiffSinger/utils/hparams.py", "w") as file:
            file.writelines(lines)
    #incase if anyone wanna change it lmao
    search_text_alt = "        args_work_dir = '"
    replacement_alt = f"        args_work_dir = '{acoustic_folder_path}'"
    with open("/workspace/content/DiffSinger/utils/hparams.py", "r") as file:
        lines = file.readlines()
    for i, line in enumerate(lines):
        if search_text_alt in line:
            lines[i] = replacement_alt + "\n"
            break
    with open("/workspace/content/DiffSinger/utils/hparams.py", "w") as file:
            file.writelines(lines)

    acoustic_folder_name = "/workspace/content/DiffSinger/" + acoustic_folder_name
    
    if no_output:
        # !python /workspace/content/DiffSinger/scripts/export.py acoustic --exp {acoustic_folder_name.replace("_acoustic", "")} --out {exp_folder}/onnx/acoustic >/dev/null 2>&1
    else:
        # !python /workspace/content/DiffSinger/scripts/export.py acoustic --exp {acoustic_folder_name.replace("_acoustic", "")} --out {exp_folder}/onnx/acoustic


if not variance_checkpoint_path:
    print("\n")
    print("variance ckeckpoint path not specified, not exporting variance ONNX...")
else:
    print("\n")
    print("converting variance to onnx...")
    #cp stuff cus apparently exporter doesnt work without it
    # !cp {variance_folder_path}/config.yaml -r /workspace/content/DiffSinger/checkpoints/{variance_folder_name}
    search_text = "        args_work_dir = os.path.join("
    replacement = f"        args_work_dir = '{variance_folder_path}'"
    with open("/workspace/content/DiffSinger/utils/hparams.py", "r") as file:
        lines = file.readlines()
    for i, line in enumerate(lines):
        if search_text in line:
            lines[i] = replacement + "\n"
            break
    with open("/workspace/content/DiffSinger/utils/hparams.py", "w") as file:
            file.writelines(lines)
    #incase if anyone wanna change it lmao
    search_text_alt = "        args_work_dir = '"
    replacement_alt = f"        args_work_dir = '{variance_folder_path}'"
    with open("/workspace/content/DiffSinger/utils/hparams.py", "r") as file:
        lines = file.readlines()
    for i, line in enumerate(lines):
        if search_text_alt in line:
            lines[i] = replacement_alt + "\n"
            break
    with open("/workspace/content/DiffSinger/utils/hparams.py", "w") as file:
            file.writelines(lines)

    variance_folder_name = "/workspace/content/DiffSinger/" + variance_folder_name
    
    if no_output:
        # !python /workspace/content/DiffSinger/scripts/export.py variance --exp {variance_folder_name.replace("_variance", "")} --out {exp_folder}/onnx/variance >/dev/null 2>&1
    else:
        # !python /workspace/content/DiffSinger/scripts/export.py variance --exp {variance_folder_name.replace("_variance", "")} --out {exp_folder}/onnx/variance


# !mv /workspace/content/DiffSinger/MyModel_Acoustic.onnx {acoustic_onnx_exp}/acoustic.onnx
# !mv /workspace/content/DiffSinger/MyModel_Acoustic.phonemes.txt {acoustic_onnx_exp}/phonemes.txt

# !mv /workspace/content/DiffSinger/MyModel_Variance.dur.onnx {variance_onnx_exp}/dur.onnx
# !mv /workspace/content/DiffSinger/MyModel_Variance.linguistic.onnx {variance_onnx_exp}/linguistic.onnx
# !mv /workspace/content/DiffSinger/MyModel_Variance.phonemes.txt {variance_onnx_exp}/phonemes.txt
# !mv /workspace/content/DiffSinger/MyModel_Variance.pitch.onnx {variance_onnx_exp}/pitch.onnx
# !mv /workspace/content/DiffSinger/MyModel_Variance.variance.onnx {variance_onnx_exp}/variance.onnx

## No effect, so use mv code above
# if not variance_checkpoint_path:
#     folder_paths = [acoustic_onnx_exp]
# elif not acoustic_checkpoint_path:
#     folder_paths = [variance_onnx_exp]
# else:
#     folder_paths = [acoustic_onnx_exp, variance_onnx_exp]

# patterns = {"acoustic.onnx": "acoustic.onnx", "dur.onnx": "dur.onnx", "linguistic.onnx": "linguistic.onnx", "pitch.onnx": "pitch.onnx", "variance.onnx": "variance.onnx", "phonemes.txt": "phonemes.txt"}

# for folder_path in folder_paths:
#     for filename in os.listdir(folder_path):
#         for pattern, new_name in patterns.items():
#             if pattern in filename:
#                 old_path = os.path.join(folder_path, filename)
#                 new_path = os.path.join(folder_path, new_name)
#                 if os.path.exists(old_path):
#                     os.rename(old_path, new_path)
# for folder_path in folder_paths:
#     for filename in os.listdir(folder_path):
#         if "acoustic_acoustic." in filename:
#             new_filename = filename.replace("acoustic_acoustic.", "acoustic_")
#         elif "variance_variance." in filename:
#             new_filename = filename.replace("variance_variance.", "variance_")
#         else:
#             new_filename = filename
#         old_path = os.path.join(folder_path, filename)
#         new_path = os.path.join(folder_path, new_filename)
#         os.rename(old_path, new_path)

print("\n")
print("ONNX export complete! Please refer to https://github.com/xunmengshe/OpenUtau/wiki/Voicebank-Development to make your model OU compatible")
print("\n")
print("Or use the 'Build OpenUtau VB' cell to have things set up for you")
# Out:
# /workspace/content
# installing dependencies for onnx conversion...
# acoustic_folder_path /workspace/content/DiffSinger/MyModel_Acoustic
#
#
# converting acoustic to onnx...
# | found ckpt by name: /workspace/content/DiffSinger/MyModel_Acoustic
# | Hparams chains:  []
# | Hparams:
# K_step: 400, K_step_infer: 400, accumulate_grad_batches: 1, audio_num_mel_bins: 128, audio_sample_rate: 44100,
# augmentation_args: {'fixed_pitch_shifting': {'enabled': False, 'scale': 0.5, 'targets': [-5.0, 5.0]}, 'random_pitch_shifting': {'enabled': True, 'range': [-5.0, 5.0], 'scale': 0.75}, 'random_time_stretching': {'enabled': True, 'range': [0.5, 2.0], 'scale': 0.75}}, base_config: [], binarization_args: {'num_workers': 0, 'shuffle': True}, binarizer_cls: preprocessing.acoustic_binarizer.AcousticBinarizer, binary_data_dir: /workspace/content/DiffSinger/MyModel_Acoustic/binary,
# breathiness_smooth_width: 0.12, clip_grad_norm: 1, dataloader_prefetch_factor: 2, dataset_size_key: lengths, dictionary: dictionaries/custom_dict.txt,
# diff_accelerator: ddim, diff_decoder_type: wavenet, diff_loss_type: l2, diff_speedup: 10, dilation_cycle_length: 4,
# dropout: 0.1, ds_workers: 4, enc_ffn_kernel_size: 9, enc_layers: 4, energy_smooth_width: 0.12,
# exp_name: /workspace/content/DiffSinger/MyModel_Acoustic, f0_embed_type: continuous, f0_max: 1100, f0_min: 65, ffn_act: gelu,
# fft_size: 2048, finetune_ckpt_path: None, finetune_enabled: False, finetune_ignored_params: ['model.fs2.encoder.embed_tokens', 'model.fs2.txt_embed', 'model.fs2.spk_embed'], finetune_strict_shapes: True,
# fmax: 16000, fmin: 40, freezing_enabled: False, frozen_params: [], hidden_size: 256,
# hop_size: 512, infer: True, lambda_aux_mel_loss: 0.2, log_interval: 100, lr_scheduler_args: {'gamma': 0.5, 'scheduler_cls': 'torch.optim.lr_scheduler.StepLR', 'step_size': 30000},
# max_batch_frames: 50000, max_batch_size: 12, max_beta: 0.02, max_updates: 200000, max_val_batch_frames: 60000,
# max_val_batch_size: 1, mel_vmax: 1.5, mel_vmin: -6.0, nccl_p2p: True, num_ckpt_keep: 5,
# num_heads: 2, num_sanity_val_steps: 1, num_spk: 1, num_valid_plots: 10, optimizer_args: {'beta1': 0.9, 'beta2': 0.98, 'lr': 0.0006, 'optimizer_cls': 'torch.optim.AdamW', 'weight_decay': 0},
# pe: rmvpe, pe_ckpt: checkpoints/rmvpe/model.pt, permanent_ckpt_interval: 20000, permanent_ckpt_start: 120000, pl_trainer_accelerator: auto,
# pl_trainer_devices: auto, pl_trainer_num_nodes: 1, pl_trainer_precision: 16-mixed, pl_trainer_strategy: {'find_unused_parameters': False, 'name': 'auto', 'process_group_backend': 'nccl'}, raw_data_dir: ['/workspace/content/raw_data/diffsinger_db/data'],
# rel_pos: True, residual_channels: 512, residual_layers: 20, sampler_frame_count_grid: 6, schedule_type: linear,
# shallow_diffusion_args: {'aux_decoder_arch': 'convnext', 'aux_decoder_args': {'dropout_rate': 0.1, 'kernel_size': 7, 'num_channels': 512, 'num_layers': 6}, 'aux_decoder_grad': 0.1, 'train_aux_decoder': True, 'train_diffusion': True, 'val_gt_start': True}, sort_by_len: True, speakers: ['data'], spec_max: [0], spec_min: [-5],
# spk_ids: [], task_cls: training.acoustic_task.AcousticTask, tension_smooth_width: 0.12, test_prefixes: ['tiger_023_seg000', 'tiger_019_seg002', 'tiger_027_seg011'], timesteps: 1000,
# use_breathiness_embed: True, use_energy_embed: True, use_key_shift_embed: True, use_pos_embed: True, use_shallow_diffusion: True,
# use_speed_embed: True, use_spk_id: False, use_tension_embed: True, use_voicing_embed: True, val_check_interval: 2000,
# val_with_vocoder: True, vocoder: NsfHifiGAN, vocoder_ckpt: /workspace/content/DiffSinger/checkpoints/nsf_hifigan_44.1k_hop512_128bin_2024.02/model.ckpt, voicing_smooth_width: 0.12, win_size: 2048,
# work_dir: /workspace/content/DiffSinger/MyModel_Acoustic,
# | Exporter: <class 'deployment.exporters.acoustic_exporter.DiffSingerAcousticExporter'>
# | load phoneme set: ['AP', 'SP', 'aa', 'ae', 'ah', 'ao', 'aw', 'ax', 'ay', 'b', 'ch', 'cl', 'd', 'dh', 'dr', 'dx', 'eh', 'er', 'ey', 'f', 'g', 'hh', 'ih', 'iy', 'jh', 'k', 'l', 'm', 'n', 'ng', 'ow', 'oy', 'p', 'q', 'r', 's', 'sh', 't', 'th', 'tr', 'uh', 'uw', 'v', 'vf', 'vtrash', 'w', 'y', 'z', 'zh']
# | load 'model' from '/workspace/content/DiffSinger/MyModel_Acoustic/model_ckpt_steps_54000.ckpt'.
# Exporting FastSpeech2Acoustic, ConvNeXtDecoder...
# /workspace/content/DiffSinger/modules/commons/espnet_positional_embedding.py:27: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if self.pe.size(1) >= x.size(1):
# /usr/local/lib/python3.10/dist-packages/torch/onnx/_internal/jit_utils.py:258: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:687: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:687: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:1178: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:1178: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# Tracing WaveNet denoiser...
# Scripting GaussianDiffusion...
# Exporting GaussianDiffusion...
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:823: UserWarning: no signature found for <torch.ScriptMethod object at 0x7fbad24a09a0>, skipping _decide_input_format
#   warnings.warn(f"{e}, skipping _decide_input_format")
# /usr/local/lib/python3.10/dist-packages/torch/onnx/symbolic_helper.py:710: UserWarning: Type cannot be inferred, which might cause exported graph to produce incorrect results.
#   warnings.warn(
# Running ONNX Simplifier on FastSpeech2Acoustic, ConvNeXtDecoder...
# | optimize graph: FastSpeech2Acoustic, ConvNeXtDecoder
# | override shape of 'mel' with (1, 'n_frames', 128)
# Running ONNX Simplifier #1 on GaussianDiffusion...
# | fold nodes: ['/diffusion/denoise_fn/Shape', '/diffusion/denoise_fn/Gather', '/diffusion/denoise_fn/Equal', '/diffusion/denoise_fn/If'] -> '/diffusion/denoise_fn/Squeeze'
# | fold nodes: ['/diffusion/denoise_fn_1/Shape', '/diffusion/denoise_fn_1/Gather', '/diffusion/denoise_fn_1/Equal', '/diffusion/denoise_fn_1/If'] -> '/diffusion/denoise_fn_1/Squeeze'
# | fold nodes: ['/diffusion/Shape_3', '/diffusion/Gather_14', '/diffusion/Equal', '/diffusion/If_3'] -> '/diffusion/Squeeze_3'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.19/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.18/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.17/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.16/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.15/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.14/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.13/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.12/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.11/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.10/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.9/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.8/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.7/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.6/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.5/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.4/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.3/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.2/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.1/conditioner_projection/Conv'
# | extract conditioner projection: '/diffusion/denoise_fn/residual_layers.0/conditioner_projection/Conv'
# | remove unused initializer: /diffusion/denoise_fn/Constant_1_output_0
# | remove unused value info: /diffusion/denoise_fn/Shape_output_0
# | remove unused value info: /diffusion/denoise_fn/Gather_output_0
# | remove unused value info: /diffusion/denoise_fn/Equal_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.0/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.1/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.2/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.3/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.4/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.5/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.6/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.7/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.8/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.9/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.10/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.11/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.12/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.13/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.14/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.15/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.16/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.17/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.18/conditioner_projection/Conv_output_0
# | remove unused value info: /diffusion/denoise_fn/residual_layers.19/conditioner_projection/Conv_output_0
# | remove unused initializer: /diffusion/denoise_fn_1/Constant_1_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Shape_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Gather_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Equal_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_1_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_4_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_7_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_10_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_13_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_16_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_19_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_22_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_25_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_28_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_31_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_34_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_37_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_40_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_43_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_46_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_49_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_52_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_55_output_0
# | remove unused value info: /diffusion/denoise_fn_1/Conv_58_output_0
# | remove unused value info: /diffusion/Shape_3_output_0
# | remove unused value info: /diffusion/Gather_14_output_0
# | remove unused value info: /diffusion/Equal_output_0
# Running ONNX Simplifier #2 on GaussianDiffusion...
# | optimize graph: GaussianDiffusion
# | add prefix: unk__0 -> fs2aux.unk__0
# | add prefix: unk__0 -> fs2aux.unk__0
# | add prefix: unk__2 -> fs2aux.unk__2
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__2 -> fs2aux.unk__2
# | add prefix: unk__2 -> fs2aux.unk__2
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__4 -> fs2aux.unk__4
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__4 -> fs2aux.unk__4
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__5 -> fs2aux.unk__5
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__3 -> fs2aux.unk__3
# | add prefix: unk__6 -> fs2aux.unk__6
# | add prefix: unk__8 -> fs2aux.unk__8
# | add prefix: unk__11 -> fs2aux.unk__11
# | add prefix: unk__13 -> fs2aux.unk__13
# | add prefix: unk__14 -> fs2aux.unk__14
# | add prefix: unk__15 -> fs2aux.unk__15
# | add prefix: unk__16 -> fs2aux.unk__16
# | add prefix: unk__17 -> fs2aux.unk__17
# | add prefix: unk__18 -> fs2aux.unk__18
# | add prefix: unk__19 -> fs2aux.unk__19
# | add prefix: unk__20 -> fs2aux.unk__20
# | add prefix: unk__21 -> fs2aux.unk__21
# | add prefix: unk__22 -> fs2aux.unk__22
# | add prefix: unk__23 -> fs2aux.unk__23
# | add prefix: unk__24 -> fs2aux.unk__24
# | add prefix: unk__25 -> fs2aux.unk__25
# | add prefix: unk__26 -> fs2aux.unk__26
# | add prefix: unk__27 -> fs2aux.unk__27
# | add prefix: unk__28 -> fs2aux.unk__28
# | add prefix: unk__29 -> fs2aux.unk__29
# | add prefix: unk__30 -> fs2aux.unk__30
# | add prefix: unk__31 -> fs2aux.unk__31
# | add prefix: unk__32 -> fs2aux.unk__32
# | add prefix: unk__33 -> fs2aux.unk__33
# | add prefix: unk__34 -> fs2aux.unk__34
# | add prefix: unk__35 -> fs2aux.unk__35
# | add prefix: unk__36 -> fs2aux.unk__36
# | add prefix: unk__37 -> fs2aux.unk__37
# | add prefix: unk__38 -> fs2aux.unk__38
# | add prefix: unk__39 -> fs2aux.unk__39
# | add prefix: unk__40 -> fs2aux.unk__40
# | add prefix: unk__11 -> fs2aux.unk__11
# | add prefix: unk__6 -> fs2aux.unk__6
# | add prefix: unk__6 -> fs2aux.unk__6
# | add prefix: unk__6 -> fs2aux.unk__6
# | add prefix: unk__6 -> fs2aux.unk__6
# | add prefix: unk__6 -> fs2aux.unk__6
# | add prefix: unk__6 -> fs2aux.unk__6
# | add prefix: unk__42 -> fs2aux.unk__42
# | add prefix: unk__43 -> fs2aux.unk__43
# | add prefix: unk__44 -> fs2aux.unk__44
# | add prefix: unk__46 -> fs2aux.unk__46
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__47 -> fs2aux.unk__47
# | add prefix: unk__48 -> fs2aux.unk__48
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__49 -> fs2aux.unk__49
# | add prefix: unk__50 -> fs2aux.unk__50
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__51 -> fs2aux.unk__51
# | add prefix: unk__52 -> fs2aux.unk__52
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__53 -> fs2aux.unk__53
# | add prefix: unk__54 -> fs2aux.unk__54
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__55 -> fs2aux.unk__55
# | add prefix: unk__56 -> fs2aux.unk__56
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__57 -> fs2aux.unk__57
# | add prefix: unk__58 -> fs2aux.unk__58
# | add prefix: unk__59 -> fs2aux.unk__59
# | add prefix: unk__59 -> fs2aux.unk__59
# | add prefix: unk__59 -> fs2aux.unk__59
# | add prefix: unk__0 -> diffusion.unk__0
# | add prefix: unk__1 -> diffusion.unk__1
# | add prefix: unk__2 -> diffusion.unk__2
# | add prefix: unk__3 -> diffusion.unk__3
# | add prefix: unk__0 -> diffusion.unk__0
# | add prefix: unk__1 -> diffusion.unk__1
# | add prefix: unk__2 -> diffusion.unk__2
# | add prefix: unk__3 -> diffusion.unk__3
# | add prefix: unk__4 -> diffusion.unk__4
# | add prefix: unk__5 -> diffusion.unk__5
# | add prefix: unk__5 -> diffusion.unk__5
# | add prefix: unk__11 -> diffusion.unk__11
# | add prefix: unk__12 -> diffusion.unk__12
# | add prefix: unk__13 -> diffusion.unk__13
# | add prefix: unk__14 -> diffusion.unk__14
# | add prefix: unk__26 -> diffusion.unk__26
# | add prefix: unk__27 -> diffusion.unk__27
# | add prefix: unk__28 -> diffusion.unk__28
# | add prefix: unk__29 -> diffusion.unk__29
# | add prefix: unk__30 -> diffusion.unk__30
# | add prefix: unk__31 -> diffusion.unk__31
# | add prefix: unk__32 -> diffusion.unk__32
# | add prefix: unk__33 -> diffusion.unk__33
# | add prefix: unk__34 -> diffusion.unk__34
# | add prefix: unk__35 -> diffusion.unk__35
# | add prefix: unk__36 -> diffusion.unk__36
# | add prefix: unk__37 -> diffusion.unk__37
# | add prefix: unk__38 -> diffusion.unk__38
# | add prefix: unk__39 -> diffusion.unk__39
# | add prefix: unk__40 -> diffusion.unk__40
# | add prefix: unk__41 -> diffusion.unk__41
# | add prefix: unk__42 -> diffusion.unk__42
# | add prefix: unk__43 -> diffusion.unk__43
# | add prefix: unk__44 -> diffusion.unk__44
# | add prefix: unk__45 -> diffusion.unk__45
# | add prefix: unk__55 -> diffusion.unk__55
# | add prefix: unk__56 -> diffusion.unk__56
# | add prefix: unk__57 -> diffusion.unk__57
# | add prefix: unk__58 -> diffusion.unk__58
# | add prefix: unk__55 -> diffusion.unk__55
# | add prefix: unk__57 -> diffusion.unk__57
# | add prefix: unk__58 -> diffusion.unk__58
# | add prefix: unk__55 -> diffusion.unk__55
# | add prefix: unk__58 -> diffusion.unk__58
# | add prefix: unk__57 -> diffusion.unk__57
# | add prefix: unk__55 -> diffusion.unk__55
# | add prefix: unk__58 -> diffusion.unk__58
# | add prefix: unk__57 -> diffusion.unk__57
# | add prefix: unk__6 -> diffusion.unk__6
# | add prefix: unk__6 -> diffusion.unk__6
# | add prefix: unk__6 -> diffusion.unk__6
# | add prefix: unk__6 -> diffusion.unk__6
# | add prefix: unk__0 -> diffusion.unk__0
# | add prefix: unk__1 -> diffusion.unk__1
# | add prefix: unk__2 -> diffusion.unk__2
# | add prefix: unk__3 -> diffusion.unk__3
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: x.63_dim_2 -> diffusion.x.63_dim_2
# | add prefix: x.63_dim_3 -> diffusion.x.63_dim_3
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__46 -> diffusion.unk__46
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__46 -> diffusion.unk__46
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__46 -> diffusion.unk__46
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__47 -> diffusion.unk__47
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__48 -> diffusion.unk__48
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: x.63_dim_1 -> diffusion.x.63_dim_1
# | add prefix: x.63_dim_2 -> diffusion.x.63_dim_2
# | add prefix: x.63_dim_3 -> diffusion.x.63_dim_3
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: x.63_dim_2 -> diffusion.x.63_dim_2
# | add prefix: x.63_dim_3 -> diffusion.x.63_dim_3
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__49 -> diffusion.unk__49
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__49 -> diffusion.unk__49
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__49 -> diffusion.unk__49
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__50 -> diffusion.unk__50
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: unk__51 -> diffusion.unk__51
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: x.63_dim_1 -> diffusion.x.63_dim_1
# | add prefix: x.63_dim_2 -> diffusion.x.63_dim_2
# | add prefix: x.63_dim_3 -> diffusion.x.63_dim_3
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: x.63_dim_1 -> diffusion.x.63_dim_1
# | add prefix: x.63_dim_2 -> diffusion.x.63_dim_2
# | add prefix: x.63_dim_3 -> diffusion.x.63_dim_3
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: x.63_dim_1 -> diffusion.x.63_dim_1
# | add prefix: x.63_dim_2 -> diffusion.x.63_dim_2
# | add prefix: x.63_dim_3 -> diffusion.x.63_dim_3
# | add prefix: x.63_dim_0 -> diffusion.x.63_dim_0
# | add prefix: x.63_dim_1 -> diffusion.x.63_dim_1
# | add prefix: x.63_dim_2 -> diffusion.x.63_dim_2
# | add prefix: x.63_dim_3 -> diffusion.x.63_dim_3
# Merging FastSpeech2Acoustic, ConvNeXtDecoder and GaussianDiffusion back into DiffSingerAcoustic...
# Running ONNX Simplifier on DiffSingerAcoustic...
# | optimize graph: DiffSingerAcoustic
# | export model => /workspace/content/DiffSinger/MyModel_Acoustic.onnx
# | export dictionary => /workspace/content/DiffSinger/MyModel_export/onnx/acoustic/dictionary.txt
# | export phonemes => /workspace/content/DiffSinger/MyModel_Acoustic.phonemes.txt
# | export configs => /workspace/content/DiffSinger/MyModel_export/onnx/acoustic/dsconfig.yaml **PLEASE EDIT BEFORE USE**
#
#
# converting variance to onnx...
# | found ckpt by name: /workspace/content/DiffSinger/MyModel_Variance
# | Hparams chains:  []
# | Hparams:
# K_step: 1000, accumulate_grad_batches: 1, audio_sample_rate: 44100, base_config: [], binarization_args: {'num_workers': 0, 'prefer_ds': False, 'shuffle': True},
# binarizer_cls: preprocessing.variance_binarizer.VarianceBinarizer, binary_data_dir: /workspace/content/DiffSinger/MyModel_Variance/binary, breathiness_db_max: -20.0, breathiness_db_min: -96.0, breathiness_smooth_width: 0.12,
# clip_grad_norm: 1, dataloader_prefetch_factor: 2, dataset_size_key: lengths, dictionary: dictionaries/custom_dict.txt, diff_accelerator: ddim,
# diff_decoder_type: wavenet, diff_loss_type: l2, diff_speedup: 10, dropout: 0.1, ds_workers: 4,
# dur_prediction_args: {'arch': 'fs2', 'dropout': 0.1, 'hidden_size': 512, 'kernel_size': 3, 'lambda_pdur_loss': 0.3, 'lambda_sdur_loss': 3.0, 'lambda_wdur_loss': 1.0, 'log_offset': 1.0, 'loss_type': 'mse', 'num_layers': 5}, enc_ffn_kernel_size: 9, enc_layers: 4, energy_db_max: -12.0, energy_db_min: -96.0,
# energy_smooth_width: 0.12, exp_name: /workspace/content/DiffSinger/MyModel_Variance, f0_max: 1100, f0_min: 65, ffn_act: gelu,
# fft_size: 2048, finetune_ckpt_path: None, finetune_enabled: False, finetune_ignored_params: ['model.spk_embed', 'model.fs2.txt_embed', 'model.fs2.encoder.embed_tokens'], finetune_strict_shapes: True,
# freezing_enabled: False, frozen_params: [], glide_embed_scale: 11.31370849898476, glide_types: ['up', 'down'], hidden_size: 256,
# hop_size: 512, infer: True, lambda_dur_loss: 1.0, lambda_pitch_loss: 1.0, lambda_var_loss: 1.0,
# log_interval: 100, lr_scheduler_args: {'gamma': 0.75, 'scheduler_cls': 'torch.optim.lr_scheduler.StepLR', 'step_size': 12000}, max_batch_frames: 80000, max_batch_size: 12, max_beta: 0.02,
# max_updates: 288000, max_val_batch_frames: 60000, max_val_batch_size: 1, melody_encoder_args: {'enc_layers': 4, 'hidden_size': 128}, midi_smooth_width: 0.06,
# nccl_p2p: True, num_ckpt_keep: 5, num_heads: 2, num_sanity_val_steps: 1, num_spk: 1,
# num_valid_plots: 10, optimizer_args: {'beta1': 0.9, 'beta2': 0.98, 'lr': 0.0006, 'optimizer_cls': 'torch.optim.AdamW', 'weight_decay': 0}, pe: rmvpe, pe_ckpt: /workspace/content/DiffSinger/checkpoints/rmvpe/model.pt, permanent_ckpt_interval: 10000,
# permanent_ckpt_start: 180000, pitch_prediction_args: {'dilation_cycle_length': 5, 'pitd_clip_max': 12.0, 'pitd_clip_min': -12.0, 'pitd_norm_max': 8.0, 'pitd_norm_min': -8.0, 'repeat_bins': 64, 'residual_channels': 256, 'residual_layers': 20}, pl_trainer_accelerator: auto, pl_trainer_devices: auto, pl_trainer_num_nodes: 1,
# pl_trainer_precision: 16-mixed, pl_trainer_strategy: {'find_unused_parameters': False, 'name': 'auto', 'process_group_backend': 'nccl'}, predict_breathiness: True, predict_dur: True, predict_energy: True,
# predict_pitch: True, predict_tension: True, predict_voicing: True, raw_data_dir: ['/workspace/content/raw_data/diffsinger_db/data'], rel_pos: True,
# sampler_frame_count_grid: 6, schedule_type: linear, sort_by_len: True, speakers: ['data'], spk_ids: [],
# task_cls: training.variance_task.VarianceTask, tension_logit_max: 10.0, tension_logit_min: -10.0, tension_smooth_width: 0.12, test_prefixes: ['tiger_027_seg028', 'tiger_028_seg018', 'tiger_028_seg011'],
# timesteps: 1000, use_glide_embed: False, use_melody_encoder: False, use_pos_embed: True, use_spk_id: False,
# val_check_interval: 2000, variances_prediction_args: {'dilation_cycle_length': 4, 'residual_channels': 192, 'residual_layers': 10, 'total_repeat_bins': 48}, voicing_db_max: -12.0, voicing_db_min: -96.0, voicing_smooth_width: 0.12,
# win_size: 2048, work_dir: /workspace/content/DiffSinger/MyModel_Variance,
# | Exporter: <class 'deployment.exporters.variance_exporter.DiffSingerVarianceExporter'>
# | load phoneme set: ['AP', 'SP', 'aa', 'ae', 'ah', 'ao', 'aw', 'ax', 'ay', 'b', 'ch', 'cl', 'd', 'dh', 'dr', 'dx', 'eh', 'er', 'ey', 'f', 'g', 'hh', 'ih', 'iy', 'jh', 'k', 'l', 'm', 'n', 'ng', 'ow', 'oy', 'p', 'q', 'r', 's', 'sh', 't', 'th', 'tr', 'uh', 'uw', 'v', 'vf', 'vtrash', 'w', 'y', 'z', 'zh']
# | load 'model' from '/workspace/content/DiffSinger/MyModel_Variance/model_ckpt_steps_64000.ckpt'.
# Exporting FastSpeech2Variance...
# /workspace/content/DiffSinger/modules/commons/espnet_positional_embedding.py:27: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if self.pe.size(1) >= x.size(1):
# /usr/local/lib/python3.10/dist-packages/torch/onnx/_internal/jit_utils.py:258: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:687: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:687: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:1178: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:1178: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:179.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# Exporting DurationPredictor...
# /usr/local/lib/python3.10/dist-packages/torch/onnx/_internal/jit_utils.py:258: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at ../torch/csrc/jit/passes/onnx/shape_type_inference.cpp:1884.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# Tracing WaveNet denoiser...
# Scripting PitchDiffusion...
# Exporting PitchDiffusion...
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:823: UserWarning: no signature found for <torch.ScriptMethod object at 0x7f8e24837e20>, skipping _decide_input_format
#   warnings.warn(f"{e}, skipping _decide_input_format")
# /usr/local/lib/python3.10/dist-packages/torch/onnx/symbolic_helper.py:710: UserWarning: Type cannot be inferred, which might cause exported graph to produce incorrect results.
#   warnings.warn(
# Tracing WaveNet denoiser...
# Scripting MultiVarianceDiffusion...
# Exporting MultiVarianceDiffusion...
# /usr/local/lib/python3.10/dist-packages/torch/onnx/utils.py:823: UserWarning: no signature found for <torch.ScriptMethod object at 0x7f8e0c5836a0>, skipping _decide_input_format
#   warnings.warn(f"{e}, skipping _decide_input_format")
# | override shape of 'encoder_out' with (1, 'n_tokens', 256)
# Running ONNX Simplifier on FastSpeech2Variance...
# | optimize graph: FastSpeech2Variance
# | export linguistic encoder => /workspace/content/DiffSinger/MyModel_Variance.linguistic.onnx
# | override shape of 'ph_dur_pred' with (1, 'n_tokens')
# Running ONNX Simplifier on DurationPredictor...
# | optimize graph: DurationPredictor
# | export dur predictor => /workspace/content/DiffSinger/MyModel_Variance.dur.onnx
# | override shape of 'pitch_cond' with (1, 'n_frames', 256)
# Running ONNX Simplifier #1 on PitchDiffusion...
# | fold nodes: ['/pitch_predictor/denoise_fn/Shape', '/pitch_predictor/denoise_fn/Gather', '/pitch_predictor/denoise_fn/Equal', '/pitch_predictor/denoise_fn/If'] -> '/pitch_predictor/denoise_fn/Squeeze'
# | fold nodes: ['/pitch_predictor/denoise_fn_1/Shape', '/pitch_predictor/denoise_fn_1/Gather', '/pitch_predictor/denoise_fn_1/Equal', '/pitch_predictor/denoise_fn_1/If'] -> '/pitch_predictor/denoise_fn_1/Squeeze'
# | fold nodes: ['/pitch_predictor/Shape_3', '/pitch_predictor/Gather_12', '/pitch_predictor/Equal', '/pitch_predictor/If_1'] -> '/pitch_predictor/Squeeze_3'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.19/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.18/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.17/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.16/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.15/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.14/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.13/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.12/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.11/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.10/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.9/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.8/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.7/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.6/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.5/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.4/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.3/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.2/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.1/conditioner_projection/Conv'
# | extract conditioner projection: '/pitch_predictor/denoise_fn/residual_layers.0/conditioner_projection/Conv'
# | remove unused initializer: /pitch_predictor/denoise_fn/Constant_1_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/Shape_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/Gather_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/Equal_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.0/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.1/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.2/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.3/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.4/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.5/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.6/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.7/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.8/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.9/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.10/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.11/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.12/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.13/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.14/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.15/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.16/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.17/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.18/conditioner_projection/Conv_output_0
# | remove unused value info: /pitch_predictor/denoise_fn/residual_layers.19/conditioner_projection/Conv_output_0
# | remove unused initializer: /pitch_predictor/denoise_fn_1/Constant_1_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Shape_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Gather_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Equal_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_1_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_4_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_7_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_10_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_13_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_16_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_19_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_22_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_25_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_28_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_31_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_34_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_37_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_40_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_43_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_46_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_49_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_52_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_55_output_0
# | remove unused value info: /pitch_predictor/denoise_fn_1/Conv_58_output_0
# | remove unused value info: /pitch_predictor/Shape_3_output_0
# | remove unused value info: /pitch_predictor/Gather_12_output_0
# | remove unused value info: /pitch_predictor/Equal_output_0
# Running ONNX Simplifier #2 on PitchDiffusion...
# | add prefix: /lr/Shape -> /pre/lr/Shape
# | add prefix: /lr/Gather -> /pre/lr/Gather
# | add prefix: /lr/Add -> /pre/lr/Add
# | add prefix: /lr/Range -> /pre/lr/Range
# | add prefix: /lr/Unsqueeze_1 -> /pre/lr/Unsqueeze_1
# | add prefix: /lr/CumSum -> /pre/lr/CumSum
# | add prefix: /lr/Pad -> /pre/lr/Pad
# | add prefix: /lr/ReduceSum -> /pre/lr/ReduceSum
# | add prefix: /lr/ReduceMax -> /pre/lr/ReduceMax
# | add prefix: /lr/Range_1 -> /pre/lr/Range_1
# | add prefix: /lr/Unsqueeze_3 -> /pre/lr/Unsqueeze_3
# | add prefix: /lr/Unsqueeze_4 -> /pre/lr/Unsqueeze_4
# | add prefix: /lr/GreaterOrEqual -> /pre/lr/GreaterOrEqual
# | add prefix: /lr/Unsqueeze_5 -> /pre/lr/Unsqueeze_5
# | add prefix: /lr/Less -> /pre/lr/Less
# | add prefix: /lr/And -> /pre/lr/And
# | add prefix: /lr/Cast_5 -> /pre/lr/Cast_5
# | add prefix: /lr/Mul -> /pre/lr/Mul
# | add prefix: /lr/ReduceSum_1 -> /pre/lr/ReduceSum_1
# | add prefix: /Pad -> /pre/Pad
# | add prefix: /Unsqueeze -> /pre/Unsqueeze
# | add prefix: /Tile -> /pre/Tile
# | add prefix: /GatherElements -> /pre/GatherElements
# | add prefix: /Cast_1 -> /pre/Cast_1
# | add prefix: /Mul -> /pre/Mul
# | add prefix: /Unsqueeze_1 -> /pre/Unsqueeze_1
# | add prefix: /Mul_1 -> /pre/Mul_1
# | add prefix: /Sub -> /pre/Sub
# | add prefix: /Mul_2 -> /pre/Mul_2
# | add prefix: /Add -> /pre/Add
# | add prefix: /Add_1 -> /pre/Add_1
# | add prefix: /lr_1/Shape -> /pre/lr_1/Shape
# | add prefix: /lr_1/Gather -> /pre/lr_1/Gather
# | add prefix: /lr_1/Add -> /pre/lr_1/Add
# | add prefix: /lr_1/Range -> /pre/lr_1/Range
# | add prefix: /lr_1/Unsqueeze_1 -> /pre/lr_1/Unsqueeze_1
# | add prefix: /lr_1/CumSum -> /pre/lr_1/CumSum
# | add prefix: /lr_1/Pad -> /pre/lr_1/Pad
# | add prefix: /lr_1/ReduceSum -> /pre/lr_1/ReduceSum
# | add prefix: /lr_1/ReduceMax -> /pre/lr_1/ReduceMax
# | add prefix: /lr_1/Range_1 -> /pre/lr_1/Range_1
# | add prefix: /lr_1/Unsqueeze_3 -> /pre/lr_1/Unsqueeze_3
# | add prefix: /lr_1/Unsqueeze_4 -> /pre/lr_1/Unsqueeze_4
# | add prefix: /lr_1/GreaterOrEqual -> /pre/lr_1/GreaterOrEqual
# | add prefix: /lr_1/Unsqueeze_5 -> /pre/lr_1/Unsqueeze_5
# | add prefix: /lr_1/Less -> /pre/lr_1/Less
# | add prefix: /lr_1/And -> /pre/lr_1/And
# | add prefix: /lr_1/Cast_5 -> /pre/lr_1/Cast_5
# | add prefix: /lr_1/Mul -> /pre/lr_1/Mul
# | add prefix: /lr_1/ReduceSum_1 -> /pre/lr_1/ReduceSum_1
# | add prefix: /Pad_1 -> /pre/Pad_1
# | add prefix: /GatherElements_1 -> /pre/GatherElements_1
# | add prefix: /smooth/Pad -> /pre/smooth/Pad
# | add prefix: /smooth/Unsqueeze -> /pre/smooth/Unsqueeze
# | add prefix: /smooth/Conv -> /pre/smooth/Conv
# | add prefix: /smooth/Squeeze -> /pre/smooth/Squeeze
# | add prefix: /Mul_3 -> /pre/Mul_3
# | add prefix: /Not -> /pre/Not
# | add prefix: /Cast_4 -> /pre/Cast_4
# | add prefix: /Mul_4 -> /pre/Mul_4
# | add prefix: /Add_2 -> /pre/Add_2
# | add prefix: /Unsqueeze_2 -> /pre/Unsqueeze_2
# | add prefix: /Add_3 -> /pre/Add_3
# | add prefix: unk__0 -> pre.unk__0
# | add prefix: unk__0 -> pre.unk__0
# | add prefix: unk__2 -> pre.unk__2
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__2 -> pre.unk__2
# | add prefix: unk__2 -> pre.unk__2
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__4 -> pre.unk__4
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__4 -> pre.unk__4
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__5 -> pre.unk__5
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__7 -> pre.unk__7
# | add prefix: unk__10 -> pre.unk__10
# | add prefix: unk__13 -> pre.unk__13
# | add prefix: unk__13 -> pre.unk__13
# | add prefix: unk__15 -> pre.unk__15
# | add prefix: unk__16 -> pre.unk__16
# | add prefix: unk__16 -> pre.unk__16
# | add prefix: unk__18 -> pre.unk__18
# | add prefix: unk__19 -> pre.unk__19
# | add prefix: unk__19 -> pre.unk__19
# | add prefix: unk__18 -> pre.unk__18
# | add prefix: unk__18 -> pre.unk__18
# | add prefix: unk__19 -> pre.unk__19
# | add prefix: unk__19 -> pre.unk__19
# | add prefix: unk__20 -> pre.unk__20
# | add prefix: unk__19 -> pre.unk__19
# | add prefix: unk__20 -> pre.unk__20
# | add prefix: unk__19 -> pre.unk__19
# | add prefix: unk__21 -> pre.unk__21
# | add prefix: unk__19 -> pre.unk__19
# | add prefix: unk__19 -> pre.unk__19
# | add prefix: unk__23 -> pre.unk__23
# | add prefix: unk__19 -> pre.unk__19
# | add prefix: unk__25 -> pre.unk__25
# | add prefix: unk__25 -> pre.unk__25
# | add prefix: unk__26 -> pre.unk__26
# | add prefix: unk__26 -> pre.unk__26
# | add prefix: unk__27 -> pre.unk__27
# | add prefix: /Constant -> /post/Constant
# | add prefix: /Constant_1 -> /post/Constant_1
# | add prefix: /Clip -> /post/Clip
# | add prefix: /Add -> /post/Add
# | optimize graph: PitchDiffusion
# | export pitch predictor => /workspace/content/DiffSinger/MyModel_Variance.pitch.onnx
# | override shape of 'variance_cond' with (1, 'n_frames', 256)
# | override shape of 'xs_pred' with (1, 4, 'n_frames')
# Running ONNX Simplifier #1 on MultiVarianceDiffusion...
# | extract conditioner projection: '/variance_predictor/denoise_fn/9/conditioner_projection/Conv'
# | extract conditioner projection: '/variance_predictor/denoise_fn/8/conditioner_projection/Conv'
# | extract conditioner projection: '/variance_predictor/denoise_fn/7/conditioner_projection/Conv'
# | extract conditioner projection: '/variance_predictor/denoise_fn/6/conditioner_projection/Conv'
# ...
# | add prefix: /Unsqueeze_output_0 -> /pre/Unsqueeze_output_0
# | add prefix: /Tile_output_0 -> /pre/Tile_output_0
# | add prefix: /GatherElements_output_0 -> /pre/GatherElements_output_0
# | add prefix: /Unsqueeze_1_output_0 -> /pre/Unsqueeze_1_output_0
# | add prefix: /Add_output_0 -> /pre/Add_output_0
# | add prefix: /Not_output_0 -> /pre/Not_output_0
# | add prefix: /Split_output_0 -> /pre/Split_output_0
# | add prefix: /Split_output_1 -> /pre/Split_output_1
# | add prefix: /Split_output_2 -> /pre/Split_output_2
# | add prefix: /Split_output_3 -> /pre/Split_output_3
# | add prefix: /Cast_1_output_0 -> /pre/Cast_1_output_0
# | add prefix: /Cast_2_output_0 -> /pre/Cast_2_output_0
# | add prefix: /Cast_3_output_0 -> /pre/Cast_3_output_0
# | add prefix: /Cast_4_output_0 -> /pre/Cast_4_output_0
# | add prefix: /Unsqueeze_2_output_0 -> /pre/Unsqueeze_2_output_0
# | add prefix: /Mul_output_0 -> /pre/Mul_output_0
# | add prefix: /Unsqueeze_3_output_0 -> /pre/Unsqueeze_3_output_0
# | add prefix: /Mul_1_output_0 -> /pre/Mul_1_output_0
# | add prefix: /Unsqueeze_4_output_0 -> /pre/Unsqueeze_4_output_0
# | add prefix: /Mul_2_output_0 -> /pre/Mul_2_output_0
# | add prefix: /Unsqueeze_5_output_0 -> /pre/Unsqueeze_5_output_0
# | add prefix: /Mul_3_output_0 -> /pre/Mul_3_output_0
# | add prefix: /Unsqueeze_6_output_0 -> /pre/Unsqueeze_6_output_0
# | add prefix: /Unsqueeze_7_output_0 -> /pre/Unsqueeze_7_output_0
# | add prefix: /Unsqueeze_8_output_0 -> /pre/Unsqueeze_8_output_0
# | add prefix: /Unsqueeze_9_output_0 -> /pre/Unsqueeze_9_output_0
# | add prefix: /Concat_1_output_0 -> /pre/Concat_1_output_0
# | add prefix: /ReduceSum_output_0 -> /pre/ReduceSum_output_0
# | add prefix: /lr/Shape -> /pre/lr/Shape
# | add prefix: /lr/Gather -> /pre/lr/Gather
# | add prefix: /lr/Add -> /pre/lr/Add
# | add prefix: /lr/Range -> /pre/lr/Range
# | add prefix: /lr/Unsqueeze_1 -> /pre/lr/Unsqueeze_1
# | add prefix: /lr/CumSum -> /pre/lr/CumSum
# | add prefix: /lr/Pad -> /pre/lr/Pad
# | add prefix: /lr/ReduceSum -> /pre/lr/ReduceSum
# | add prefix: /lr/ReduceMax -> /pre/lr/ReduceMax
# | add prefix: /lr/Range_1 -> /pre/lr/Range_1
# | add prefix: /lr/Unsqueeze_3 -> /pre/lr/Unsqueeze_3
# | add prefix: /lr/Unsqueeze_4 -> /pre/lr/Unsqueeze_4
# | add prefix: /lr/GreaterOrEqual -> /pre/lr/GreaterOrEqual
# | add prefix: /lr/Unsqueeze_5 -> /pre/lr/Unsqueeze_5
# | add prefix: /lr/Less -> /pre/lr/Less
# | add prefix: /lr/And -> /pre/lr/And
# | add prefix: /lr/Cast_5 -> /pre/lr/Cast_5
# | add prefix: /lr/Mul -> /pre/lr/Mul
# | add prefix: /lr/ReduceSum_1 -> /pre/lr/ReduceSum_1
# | add prefix: /Pad -> /pre/Pad
# | add prefix: /Unsqueeze -> /pre/Unsqueeze
# | add prefix: /Tile -> /pre/Tile
# | add prefix: /GatherElements -> /pre/GatherElements
# | add prefix: /Unsqueeze_1 -> /pre/Unsqueeze_1
# | add prefix: /Add -> /pre/Add
# | add prefix: /Not -> /pre/Not
# | add prefix: /Split -> /pre/Split
# | add prefix: /Cast_1 -> /pre/Cast_1
# | add prefix: /Cast_2 -> /pre/Cast_2
# | add prefix: /Cast_3 -> /pre/Cast_3
# | add prefix: /Cast_4 -> /pre/Cast_4
# | add prefix: /Unsqueeze_2 -> /pre/Unsqueeze_2
# | add prefix: /Mul -> /pre/Mul
# | add prefix: /Unsqueeze_3 -> /pre/Unsqueeze_3
# | add prefix: /Mul_1 -> /pre/Mul_1
# | add prefix: /Unsqueeze_4 -> /pre/Unsqueeze_4
# | add prefix: /Mul_2 -> /pre/Mul_2
# | add prefix: /Unsqueeze_5 -> /pre/Unsqueeze_5
# | add prefix: /Mul_3 -> /pre/Mul_3
# | add prefix: /Unsqueeze_6 -> /pre/Unsqueeze_6
# | add prefix: /Unsqueeze_7 -> /pre/Unsqueeze_7
# | add prefix: /Unsqueeze_8 -> /pre/Unsqueeze_8
# | add prefix: /Unsqueeze_9 -> /pre/Unsqueeze_9
# | add prefix: /Concat_1 -> /pre/Concat_1
# | add prefix: /ReduceSum -> /pre/ReduceSum
# | add prefix: /Add_1 -> /pre/Add_1
# | add prefix: /lr/Shape_output_0 -> /pre/lr/Shape_output_0
# | add prefix: /lr/Shape_output_0 -> /pre/lr/Shape_output_0
# | add prefix: /lr/Constant_output_0 -> /pre/lr/Constant_output_0
# | add prefix: /lr/Gather_output_0 -> /pre/lr/Gather_output_0
# | add prefix: /lr/Gather_output_0 -> /pre/lr/Gather_output_0
# | add prefix: /lr/Constant_output_0 -> /pre/lr/Constant_output_0
# | add prefix: /lr/Add_output_0 -> /pre/lr/Add_output_0
# | add prefix: /lr/Constant_output_0 -> /pre/lr/Constant_output_0
# | add prefix: /lr/Add_output_0 -> /pre/lr/Add_output_0
# | add prefix: /lr/Constant_output_0 -> /pre/lr/Constant_output_0
# | add prefix: /lr/Range_output_0 -> /pre/lr/Range_output_0
# | add prefix: /lr/Range_output_0 -> /pre/lr/Range_output_0
# | add prefix: 115 -> /pre115
# | add prefix: /lr/Unsqueeze_1_output_0 -> /pre/lr/Unsqueeze_1_output_0
# | add prefix: /lr/Constant_6_output_0 -> /pre/lr/Constant_6_output_0
# | add prefix: /lr/CumSum_output_0 -> /pre/lr/CumSum_output_0
# | add prefix: /lr/CumSum_output_0 -> /pre/lr/CumSum_output_0
# | add prefix: /lr/Reshape_1_output_0 -> /pre/lr/Reshape_1_output_0
# | add prefix: /lr/Constant_15_output_0 -> /pre/lr/Constant_15_output_0
# | add prefix: /lr/Pad_output_0 -> /pre/lr/Pad_output_0
# | add prefix: /lr/Constant_11_output_0 -> /pre/lr/Constant_11_output_0
# | add prefix: /lr/ReduceSum_output_0 -> /pre/lr/ReduceSum_output_0
# | add prefix: /lr/ReduceSum_output_0 -> /pre/lr/ReduceSum_output_0
# | add prefix: /lr/ReduceMax_output_0 -> /pre/lr/ReduceMax_output_0
# | add prefix: /lr/Constant_15_output_0 -> /pre/lr/Constant_15_output_0
# | add prefix: /lr/ReduceMax_output_0 -> /pre/lr/ReduceMax_output_0
# | add prefix: /lr/Constant_output_0 -> /pre/lr/Constant_output_0
# | add prefix: /lr/Range_1_output_0 -> /pre/lr/Range_1_output_0
# | add prefix: /lr/Range_1_output_0 -> /pre/lr/Range_1_output_0
# | add prefix: 117 -> /pre117
# | add prefix: /lr/Unsqueeze_3_output_0 -> /pre/lr/Unsqueeze_3_output_0
# | add prefix: /lr/Pad_output_0 -> /pre/lr/Pad_output_0
# | add prefix: /lr/Constant_5_output_0 -> /pre/lr/Constant_5_output_0
# | add prefix: /lr/Unsqueeze_4_output_0 -> /pre/lr/Unsqueeze_4_output_0
# | add prefix: /lr/Unsqueeze_3_output_0 -> /pre/lr/Unsqueeze_3_output_0
# | add prefix: /lr/Unsqueeze_4_output_0 -> /pre/lr/Unsqueeze_4_output_0
# | add prefix: /lr/GreaterOrEqual_output_0 -> /pre/lr/GreaterOrEqual_output_0
# | add prefix: /lr/CumSum_output_0 -> /pre/lr/CumSum_output_0
# | add prefix: /lr/Constant_5_output_0 -> /pre/lr/Constant_5_output_0
# | add prefix: /lr/Unsqueeze_5_output_0 -> /pre/lr/Unsqueeze_5_output_0
# | add prefix: /lr/Unsqueeze_3_output_0 -> /pre/lr/Unsqueeze_3_output_0
# | add prefix: /lr/Unsqueeze_5_output_0 -> /pre/lr/Unsqueeze_5_output_0
# | add prefix: /lr/Less_output_0 -> /pre/lr/Less_output_0
# | add prefix: /lr/GreaterOrEqual_output_0 -> /pre/lr/GreaterOrEqual_output_0
# | add prefix: /lr/Less_output_0 -> /pre/lr/Less_output_0
# | add prefix: /lr/And_output_0 -> /pre/lr/And_output_0
# | add prefix: /lr/And_output_0 -> /pre/lr/And_output_0
# | add prefix: /lr/Cast_5_output_0 -> /pre/lr/Cast_5_output_0
# | add prefix: /lr/Unsqueeze_1_output_0 -> /pre/lr/Unsqueeze_1_output_0
# | add prefix: /lr/Cast_5_output_0 -> /pre/lr/Cast_5_output_0
# | add prefix: /lr/Mul_output_0 -> /pre/lr/Mul_output_0
# | add prefix: /lr/Mul_output_0 -> /pre/lr/Mul_output_0
# | add prefix: /lr/Constant_19_output_0 -> /pre/lr/Constant_19_output_0
# | add prefix: /lr/ReduceSum_1_output_0 -> /pre/lr/ReduceSum_1_output_0
# | add prefix: /Reshape_1_output_0 -> /pre/Reshape_1_output_0
# | add prefix: /Pad_output_0 -> /pre/Pad_output_0
# | add prefix: /lr/ReduceSum_1_output_0 -> /pre/lr/ReduceSum_1_output_0
# | add prefix: /lr/Constant_5_output_0 -> /pre/lr/Constant_5_output_0
# | add prefix: /Unsqueeze_output_0 -> /pre/Unsqueeze_output_0
# | add prefix: /Unsqueeze_output_0 -> /pre/Unsqueeze_output_0
# | add prefix: onnx::Tile_112 -> /preonnx::Tile_112
# | add prefix: /Tile_output_0 -> /pre/Tile_output_0
# | add prefix: /Pad_output_0 -> /pre/Pad_output_0
# | add prefix: /Tile_output_0 -> /pre/Tile_output_0
# | add prefix: /GatherElements_output_0 -> /pre/GatherElements_output_0
# | add prefix: /lr/Constant_5_output_0 -> /pre/lr/Constant_5_output_0
# | add prefix: /Unsqueeze_1_output_0 -> /pre/Unsqueeze_1_output_0
# | add prefix: /Unsqueeze_1_output_0 -> /pre/Unsqueeze_1_output_0
# | add prefix: onnx::MatMul_181 -> /preonnx::MatMul_181
# | add prefix: /GatherElements_output_0 -> /pre/GatherElements_output_0
# | add prefix: /Add_output_0 -> /pre/Add_output_0
# | add prefix: /Not_output_0 -> /pre/Not_output_0
# | add prefix: /Not_output_0 -> /pre/Not_output_0
# | add prefix: /Constant_11_output_0 -> /pre/Constant_11_output_0
# | add prefix: /Split_output_0 -> /pre/Split_output_0
# | add prefix: /Split_output_1 -> /pre/Split_output_1
# | add prefix: /Split_output_2 -> /pre/Split_output_2
# | add prefix: /Split_output_3 -> /pre/Split_output_3
# | add prefix: /Split_output_0 -> /pre/Split_output_0
# | add prefix: /Cast_1_output_0 -> /pre/Cast_1_output_0
# | add prefix: /Split_output_1 -> /pre/Split_output_1
# | add prefix: /Cast_2_output_0 -> /pre/Cast_2_output_0
# | add prefix: /Split_output_2 -> /pre/Split_output_2
# | add prefix: /Cast_3_output_0 -> /pre/Cast_3_output_0
# | add prefix: /Split_output_3 -> /pre/Split_output_3
# | add prefix: /Cast_4_output_0 -> /pre/Cast_4_output_0
# | add prefix: /lr/Constant_5_output_0 -> /pre/lr/Constant_5_output_0
# | add prefix: /Unsqueeze_2_output_0 -> /pre/Unsqueeze_2_output_0
# | add prefix: /Unsqueeze_2_output_0 -> /pre/Unsqueeze_2_output_0
# | add prefix: onnx::MatMul_182 -> /preonnx::MatMul_182
# | add prefix: /Cast_1_output_0 -> /pre/Cast_1_output_0
# | add prefix: /Mul_output_0 -> /pre/Mul_output_0
# | add prefix: /lr/Constant_5_output_0 -> /pre/lr/Constant_5_output_0
# | add prefix: /Unsqueeze_3_output_0 -> /pre/Unsqueeze_3_output_0
# | add prefix: /Unsqueeze_3_output_0 -> /pre/Unsqueeze_3_output_0
# | add prefix: onnx::MatMul_183 -> /preonnx::MatMul_183
# | add prefix: /Cast_2_output_0 -> /pre/Cast_2_output_0
# | add prefix: /Mul_1_output_0 -> /pre/Mul_1_output_0
# | add prefix: /lr/Constant_5_output_0 -> /pre/lr/Constant_5_output_0
# | add prefix: /Unsqueeze_4_output_0 -> /pre/Unsqueeze_4_output_0
# | add prefix: /Unsqueeze_4_output_0 -> /pre/Unsqueeze_4_output_0
# | add prefix: onnx::MatMul_184 -> /preonnx::MatMul_184
# | add prefix: /Cast_3_output_0 -> /pre/Cast_3_output_0
# | add prefix: /Mul_2_output_0 -> /pre/Mul_2_output_0
# | add prefix: /lr/Constant_5_output_0 -> /pre/lr/Constant_5_output_0
# | add prefix: /Unsqueeze_5_output_0 -> /pre/Unsqueeze_5_output_0
# | add prefix: /Unsqueeze_5_output_0 -> /pre/Unsqueeze_5_output_0
# | add prefix: onnx::MatMul_185 -> /preonnx::MatMul_185
# | add prefix: /Cast_4_output_0 -> /pre/Cast_4_output_0
# | add prefix: /Mul_3_output_0 -> /pre/Mul_3_output_0
# | add prefix: /Mul_output_0 -> /pre/Mul_output_0
# | add prefix: /lr/Constant_11_output_0 -> /pre/lr/Constant_11_output_0
# | add prefix: /Unsqueeze_6_output_0 -> /pre/Unsqueeze_6_output_0
# | add prefix: /Mul_1_output_0 -> /pre/Mul_1_output_0
# | add prefix: /lr/Constant_11_output_0 -> /pre/lr/Constant_11_output_0
# | add prefix: /Unsqueeze_7_output_0 -> /pre/Unsqueeze_7_output_0
# | add prefix: /Mul_2_output_0 -> /pre/Mul_2_output_0
# | add prefix: /lr/Constant_11_output_0 -> /pre/lr/Constant_11_output_0
# | add prefix: /Unsqueeze_8_output_0 -> /pre/Unsqueeze_8_output_0
# | add prefix: /Mul_3_output_0 -> /pre/Mul_3_output_0
# | add prefix: /lr/Constant_11_output_0 -> /pre/lr/Constant_11_output_0
# | add prefix: /Unsqueeze_9_output_0 -> /pre/Unsqueeze_9_output_0
# | add prefix: /Unsqueeze_6_output_0 -> /pre/Unsqueeze_6_output_0
# | add prefix: /Unsqueeze_7_output_0 -> /pre/Unsqueeze_7_output_0
# | add prefix: /Unsqueeze_8_output_0 -> /pre/Unsqueeze_8_output_0
# | add prefix: /Unsqueeze_9_output_0 -> /pre/Unsqueeze_9_output_0
# | add prefix: /Concat_1_output_0 -> /pre/Concat_1_output_0
# | add prefix: /Concat_1_output_0 -> /pre/Concat_1_output_0
# | add prefix: /lr/Constant_11_output_0 -> /pre/lr/Constant_11_output_0
# | add prefix: /ReduceSum_output_0 -> /pre/ReduceSum_output_0
# | add prefix: /Add_output_0 -> /pre/Add_output_0
# | add prefix: /ReduceSum_output_0 -> /pre/ReduceSum_output_0
# | add prefix: unk__0 -> pre.unk__0
# | add prefix: unk__0 -> pre.unk__0
# | add prefix: unk__2 -> pre.unk__2
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__2 -> pre.unk__2
# | add prefix: unk__2 -> pre.unk__2
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__4 -> pre.unk__4
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__4 -> pre.unk__4
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__5 -> pre.unk__5
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__3 -> pre.unk__3
# | add prefix: unk__7 -> pre.unk__7
# | add prefix: unk__10 -> pre.unk__10
# | add prefix: unk__13 -> pre.unk__13
# | add prefix: unk__13 -> pre.unk__13
# | add prefix: unk__15 -> pre.unk__15
# | add prefix: /Constant_output_0 -> /post/Constant_output_0
# | add prefix: /Constant_1_output_0 -> /post/Constant_1_output_0
# | add prefix: /Constant_5_output_0 -> /post/Constant_5_output_0
# | add prefix: /Constant_6_output_0 -> /post/Constant_6_output_0
# | add prefix: /Constant_11_output_0 -> /post/Constant_11_output_0
# | add prefix: /Constant_12_output_0 -> /post/Constant_12_output_0
# | add prefix: /Split_output_0 -> /post/Split_output_0
# | add prefix: /Split_output_1 -> /post/Split_output_1
# | add prefix: /Split_output_2 -> /post/Split_output_2
# | add prefix: /Split_output_3 -> /post/Split_output_3
# | add prefix: /Squeeze_output_0 -> /post/Squeeze_output_0
# | add prefix: /Squeeze_1_output_0 -> /post/Squeeze_1_output_0
# | add prefix: /Squeeze_2_output_0 -> /post/Squeeze_2_output_0
# | add prefix: /Squeeze_3_output_0 -> /post/Squeeze_3_output_0
# | add prefix: /Split -> /post/Split
# | add prefix: /Squeeze -> /post/Squeeze
# | add prefix: /Squeeze_1 -> /post/Squeeze_1
# | add prefix: /Squeeze_2 -> /post/Squeeze_2
# | add prefix: /Squeeze_3 -> /post/Squeeze_3
# | add prefix: /Clip -> /post/Clip
# | add prefix: /Clip_1 -> /post/Clip_1
# | add prefix: /Clip_2 -> /post/Clip_2
# | add prefix: /Clip_3 -> /post/Clip_3
# | add prefix: /Constant_output_0 -> /post/Constant_output_0
# | add prefix: /Split_output_0 -> /post/Split_output_0
# | add prefix: /Split_output_1 -> /post/Split_output_1
# | add prefix: /Split_output_2 -> /post/Split_output_2
# | add prefix: /Split_output_3 -> /post/Split_output_3
# | add prefix: /Split_output_0 -> /post/Split_output_0
# | add prefix: /Constant_1_output_0 -> /post/Constant_1_output_0
# | add prefix: /Squeeze_output_0 -> /post/Squeeze_output_0
# | add prefix: /Split_output_1 -> /post/Split_output_1
# | add prefix: /Constant_1_output_0 -> /post/Constant_1_output_0
# | add prefix: /Squeeze_1_output_0 -> /post/Squeeze_1_output_0
# | add prefix: /Split_output_2 -> /post/Split_output_2
# | add prefix: /Constant_1_output_0 -> /post/Constant_1_output_0
# | add prefix: /Squeeze_2_output_0 -> /post/Squeeze_2_output_0
# | add prefix: /Split_output_3 -> /post/Split_output_3
# | add prefix: /Constant_1_output_0 -> /post/Constant_1_output_0
# | add prefix: /Squeeze_3_output_0 -> /post/Squeeze_3_output_0
# | add prefix: /Squeeze_output_0 -> /post/Squeeze_output_0
# | add prefix: /Constant_5_output_0 -> /post/Constant_5_output_0
# | add prefix: /Constant_6_output_0 -> /post/Constant_6_output_0
# | add prefix: /Squeeze_1_output_0 -> /post/Squeeze_1_output_0
# | add prefix: /Constant_5_output_0 -> /post/Constant_5_output_0
# | add prefix: /Constant_6_output_0 -> /post/Constant_6_output_0
# | add prefix: /Squeeze_2_output_0 -> /post/Squeeze_2_output_0
# | add prefix: /Constant_5_output_0 -> /post/Constant_5_output_0
# | add prefix: /Constant_6_output_0 -> /post/Constant_6_output_0
# | add prefix: /Squeeze_3_output_0 -> /post/Squeeze_3_output_0
# | add prefix: /Constant_11_output_0 -> /post/Constant_11_output_0
# | add prefix: /Constant_12_output_0 -> /post/Constant_12_output_0
# Merging MultiVarianceDiffusion subroutines...
# | export variance predictor => /workspace/content/DiffSinger/MyModel_Variance.variance.onnx
# | export dictionary => /workspace/content/DiffSinger/MyModel_export/onnx/variance/dictionary.txt
# | export phonemes => /workspace/content/DiffSinger/MyModel_Variance.phonemes.txt
# | export configs => /workspace/content/DiffSinger/MyModel_export/onnx/variance/dsconfig.yaml **PLEASE EDIT BEFORE USE**
#
#
# ONNX export complete! Please refer to https://github.com/xunmengshe/OpenUtau/wiki/Voicebank-Development to make your model OU compatible
#
#
# Or use the 'Build OpenUtau VB' cell to have things set up for you

# %% [markdown]
# # **Build OpenUtau Voicebank**

# %%
# IMPORTANT:
# change the name in Model_export folder to acoustic.onnx, phonemes.txt....

# Build OpenUtau VB
#i need to clean this up it seems
#plan: add a build ou section here by inserting onnx paths (or just the folder containing the folders to the onnx files) to build ou
# ill have a config read function too so i dont have to add checkmark of if people train with embeds or shallow diff or not <3
# yes im lazy rawr x3
# %cd /workspace/content
import os
import shutil
import yaml

constr_folder = "/workspace/content/OU_voicebank"
if not os.path.exists(constr_folder):
    os.makedirs(constr_folder)
else:
    shutil.rmtree(constr_folder)
    os.makedirs(constr_folder)

# clear_output()

#@markdown <font size="-1.5"> path to your **ACOUSTIC ONNX FOLDER**
acoustic_onnx_folder = "/workspace/content/DiffSinger/MyModel_export/onnx/acoustic" #@param{type:"string'}
#@markdown <font size="-1.5"> path to the config.yaml of acoustic model
acoustic_config = "/workspace/content/DiffSinger/MyModel_Acoustic/config.yaml" #@param{type:"string'}

#@markdown <font size="-1.5"> path to your **VARIANCE ONNX FOLDER**
variance_onnx_folder = "/workspace/content/DiffSinger/MyModel_export/onnx/variance" #@param{type:"string'}
#@markdown <font size="-1.5"> path to the config.yaml of variance model
variance_config = "/workspace/content/DiffSinger/MyModel_Variance/config.yaml" #@param{type:"string'}

#@markdown <font size="-1.5"> path to your word to phoneme dict (leave blank to use default Japanese dict)
dictionary_path = "/workspace/content/DiffSinger/MyModel_Acoustic/dictionary.txt" #@param{type:"string"}

#@markdown <font size="-1.5"> path to the folder you want to save the zip file to
save_path = "/workspace/content/DiffSinger/MyModel_export" #@param{type:"string"}

#@markdown ___

#@markdown ## Character Configuration | character.txt and character.yaml

#@markdown <font size="-1.5"> your character display name| **required**
name = "SongGen_Singer" #@param{type:"string"}
#@markdown <font size="-1.5"> your character logo | **optional**
image = "" #@param{type:"string"}
image_name = os.path.basename(image)
#@markdown <font size="-1.5"> your character portrait | **optional**
portrait = "" #@param{type:"string"}
portrait_name = os.path.basename(portrait)
#@markdown <font size="-1.5"> the author of the voicebank | **optional**
author = "" #@param{type:"string"}
#@markdown <font size="-1.5"> the voice provider of the voicebank | **optional**
voice = "" #@param{type:"string"}
#@markdown <font size="-1.5"> link to the character's website | **optional**
web = "" #@param{type:"string"}

print("copying files...")
main_stuff = f"{constr_folder}/{name}"
if not os.path.exists(main_stuff):
    os.makedirs(main_stuff)
if not os.path.exists(f"{main_stuff}/dsmain"):
    os.makedirs(f"{main_stuff}/dsmain/embeds/acoustic")
    os.makedirs(f"{main_stuff}/dsmain/embeds/variance")
# !cp {acoustic_onnx_folder}/acoustic.onnx {main_stuff}/dsmain
# !cp {acoustic_onnx_folder}/phonemes.txt {main_stuff}/dsmain
# !cp {acoustic_onnx_folder}/*.emb {main_stuff}/dsmain/embeds/acoustic >/dev/null 2>&1
# !cp {variance_onnx_folder}/*.emb {main_stuff}/dsmain/embeds/variance >/dev/null 2>&1
if image:
    # !cp {image} {main_stuff}
if portrait:
    # !cp {portrait} {main_stiff}

if variance_onnx_folder:
    # !cp {variance_onnx_folder}/linguistic.onnx {main_stuff}/dsmain
else:
    pass

print("\n")
print("writing character.txt...")
with open(f"{main_stuff}/character.txt", "w") as file:
    file.write(f"name={name}\n")
    if image:
        file.write(f"image={image_name}\n")
    if author:
        file.write(f"author={author}\n")
    if voice:
        file.write(f"voice={voice}\n")
    if web:
        file.write(f"web={web}\n")

print("\n")
print("writing character.yaml...")
with open(f"{main_stuff}/character.yaml", "w") as file:
    file.write("text_file_encoding: utf-8\n")
    if portrait:
        file.write(f"portrait: {portrait_name}\n")
        file.write("portrait_opacity: 0.45\n")
    file.write("default_phonemizer: OpenUtau.Core.DiffSinger.DiffSingerPhonemizer\n")
    file.write("singer_type: diffsinger\n")
acoustic_emb_files = os.listdir(acoustic_onnx_folder)
acoustic_embeds = []
acoustic_color_suffix = []
for file in acoustic_emb_files:
    if file.endswith(".emb"):
        acoustic_emb = os.path.splitext(file)[0]
        acoustic_embeds.append("dsmain/embeds/acoustic/" + acoustic_emb)
        acoustic_color_suffix.append(acoustic_emb)
subbanks = []
for i, (acoustic_embed_color, acoustic_embed_suffix) in enumerate(zip(acoustic_color_suffix, acoustic_embeds), start=1):
    color = f"{i:02}: {acoustic_embed_color}"
    suffix = f"{acoustic_embed_suffix}"
    subbanks.append({"color": color, "suffix": suffix})
if subbanks:
    with open(f"{main_stuff}/character.yaml", "r") as config:
        i_wanna_die_slash_j = yaml.safe_load(config)
    i_wanna_die_slash_j["subbanks"] = subbanks
    with open(f"{main_stuff}/character.yaml", "w") as config:
        yaml.dump(i_wanna_die_slash_j, config)

print("\n")
print("writing dsconfig.yaml for acoustic...")
with open(f"{main_stuff}/dsconfig.yaml", "w") as file:
    file.write("phonemes: dsmain/phonemes.txt\n")
    file.write("acoustic: dsmain/acoustic.onnx\n")
    file.write("vocoder: nsf_hifigan\n")
    file.write("singer_type: diffsinger\n")
with open(acoustic_config, "r") as config:
    mfking_config = yaml.safe_load(config)
use_energy_embed = mfking_config.get("use_energy_embed")
use_breathiness_embed = mfking_config.get("use_breathiness_embed")
use_shallow_diffusion = mfking_config.get("use_shallow_diffusion")
max_depth = mfking_config.get("K_step")
speakers = mfking_config.get("speakers") #looking back here, why is this even here lmao cus i used acoustic_embeds instead of speakers
augmentation_arg = mfking_config.get("augmentation_args")
pitch_aug = mfking_config.get("use_key_shift_embed")
time_aug = mfking_config.get("use_speed_embed")
voicing = mfking_config.get("use_voicing_embed")
tension = mfking_config.get("use_tension_embed")
with open(f"{main_stuff}/dsconfig.yaml", "r") as config:
    why_are_there_so_many_i_could_prob_make_it_one = yaml.safe_load(config)
why_are_there_so_many_i_could_prob_make_it_one["use_energy_embed"] = use_energy_embed
why_are_there_so_many_i_could_prob_make_it_one["use_breathiness_embed"] = use_breathiness_embed
why_are_there_so_many_i_could_prob_make_it_one["use_shallow_diffusion"] = use_shallow_diffusion
why_are_there_so_many_i_could_prob_make_it_one["max_depth"] = max_depth
why_are_there_so_many_i_could_prob_make_it_one["augmentation_args"] = augmentation_arg
why_are_there_so_many_i_could_prob_make_it_one["use_key_shift_embed"] = pitch_aug
why_are_there_so_many_i_could_prob_make_it_one["use_speed_embed"] = time_aug
why_are_there_so_many_i_could_prob_make_it_one["use_voicing_embed"] = voicing
why_are_there_so_many_i_could_prob_make_it_one["use_tension_embed"] = tension

if subbanks:
    why_are_there_so_many_i_could_prob_make_it_one["speakers"] = acoustic_embeds
with open(f"{main_stuff}/dsconfig.yaml", "w") as config:
    yaml.dump(why_are_there_so_many_i_could_prob_make_it_one, config)


variance_emb_files = os.listdir(variance_onnx_folder)
variance_embeds = []
for file in variance_emb_files:
    if file.endswith(".emb"):
        variance_emb = os.path.splitext(file)[0]
        variance_embeds.append("../dsmain/embeds/variance/" + variance_emb)

print("\n")
print("writing dsdict.yaml...")
if not dictionary_path:
    dict_path = "/workspace/content/jpn_dict.txt"
else:
    dict_path = dictionary_path

# for symbols list
phoneme_dict_path = f"{acoustic_onnx_folder}/dictionary.txt"

dsdict = "dsdict.yaml"

def parse_phonemes(phonemes_str):
    return phonemes_str.split()

entries = []
vowel_types = {"a", "i", "u", "e", "o", "N", "M", "NG", "cl", "vf"}
vowel_data = []
stop_data = []

# Process the specified dictionary
with open(dict_path, "r") as f:
    for line in f:
        word, phonemes_str = line.strip().split("\t")
        phonemes = parse_phonemes(phonemes_str)
        if len(phonemes) == 1:
            entries.append({"grapheme": word, "phonemes": phonemes})
        else:
            entries.append({"grapheme": word, "phonemes": phonemes})

with open(phoneme_dict_path, "r") as f:
    for line in f:
        phoneme, _ = line.strip().split("\t")
        phoneme_type = "vowel" if phoneme[0] in vowel_types else "stop"
        entry = {"symbol": phoneme, "type": phoneme_type}
        if phoneme_type == "vowel":
            vowel_data.append(entry)
        else:
            stop_data.append(entry)

vowel_data.sort(key=lambda x: x["symbol"])
stop_data.sort(key=lambda x: x["symbol"])

dsdict_path = os.path.join(constr_folder, dsdict)
with open(dsdict_path, "w") as f:
    f.write("entries:\n")
    for entry in entries:
        f.write(f"- grapheme: {entry['grapheme']}\n")
        f.write("  phonemes:\n")
        for phoneme in entry["phonemes"]:
            f.write(f"  - {phoneme}\n")

    f.write("\nsymbols:\n")
    for entry in vowel_data + stop_data:
        f.write(f"- symbol: {entry['symbol']}\n")
        f.write(f"  type: {entry['type']}\n")

with open(variance_config, "r") as config:
    mfking_config = yaml.safe_load(config)
sample_rate = mfking_config.get("audio_sample_rate")
hop_size = mfking_config.get("hop_size")
predict_dur = mfking_config.get("predict_dur")
predict_pitch = mfking_config.get("predict_pitch")
use_melody_encoder = mfking_config.get("use_melody_encoder")
predict_voicing = mfking_config.get("predict_voicing")
predict_tension = mfking_config.get("predict_tension")

dur_onnx_path = variance_onnx_folder + "/dur.onnx"
if os.path.exists(dur_onnx_path):
    print("\n")
    print("making dsdur directory and necessary files...")
    os.makedirs(f"{main_stuff}/dsdur")
    # !cp {dur_onnx_path} {main_stuff}/dsdur
    # !cp {dsdict_path} {main_stuff}/dsdur
    with open(f"{main_stuff}/dsdur/dsconfig.yaml", "w") as file:
        file.write("phonemes: ../dsmain/phonemes.txt\n")
        file.write("linguistic: ../dsmain/linguistic.onnx\n")
        file.write("dur: dur.onnx\n")
    with open(f"{main_stuff}/dsdur/dsconfig.yaml", "r") as config:
        dsdur_config = yaml.safe_load(config)
    dsdur_config["sample_rate"] = sample_rate
    dsdur_config["hop_size"] = hop_size
    dsdur_config["predict_dur"] = predict_dur
    if subbanks:
        dsdur_config["speakers"] = variance_embeds
    with open(f"{main_stuff}/dsdur/dsconfig.yaml", "w") as config:
        yaml.dump(dsdur_config, config)
else:
    print("\n")
    print("dur.onnx not found, skipping on making dsdur folder...")

pitch_onnx_path = variance_onnx_folder + "/pitch.onnx"
if os.path.exists(pitch_onnx_path):
    print("\n")
    print("making dspitch directory and necessary files...")
    os.makedirs(f"{main_stuff}/dspitch")
    # !cp {pitch_onnx_path} {main_stuff}/dspitch
    # !cp {dsdict_path} {main_stuff}/dspitch
    with open(f"{main_stuff}/dspitch/dsconfig.yaml", "w") as file:
        file.write("phonemes: ../dsmain/phonemes.txt\n")
        file.write("linguistic: ../dsmain/linguistic.onnx\n")
        file.write("pitch: pitch.onnx\n")
        file.write("use_expr: true\n")
    with open(f"{main_stuff}/dspitch/dsconfig.yaml", "r") as config:
        dspitch_config = yaml.safe_load(config)
    dspitch_config["sample_rate"] = sample_rate
    dspitch_config["hop_size"] = hop_size
    dspitch_config["predict_dur"] = predict_pitch
    if subbanks:
        dspitch_config["speakers"] = variance_embeds
    dspitch_config["use_note_rest"] = use_melody_encoder
    with open(f"{main_stuff}/dspitch/dsconfig.yaml", "w") as config:
        yaml.dump(dspitch_config, config)
else:
    print("\n")
    print("pitch.onnx not found, skipping on making dspitch folder...")

variance_onnx_path = variance_onnx_folder + "/variance.onnx"
if os.path.exists(variance_onnx_path):
    print("\n")
    print("making dsvariance directory and necessary files...")
    os.makedirs(f"{main_stuff}/dsvariance")
    # !cp {variance_onnx_path} {main_stuff}/dsvariance
    # !cp {dsdict_path} {main_stuff}/dsvariance
    with open(f"{main_stuff}/dsvariance/dsconfig.yaml", "w") as file:
        file.write("phonemes: ../dsmain/phonemes.txt\n")
        file.write("linguistic: ../dsmain/linguistic.onnx\n")
        file.write("variance: variance.onnx\n")
    with open(f"{main_stuff}/dsvariance/dsconfig.yaml", "r") as config:
        dsvariance_config = yaml.safe_load(config)
    dsvariance_config["sample_rate"] = sample_rate
    dsvariance_config["hop_size"] = hop_size
    dsvariance_config["predict_dur"] = True #this one will always be true cus if there's no variance model, it shouldnt make this folder in the first place
    dsvariance_config["predict_voicing"] = predict_voicing
    dsvariance_config["predict_tension"] = predict_tension
    if subbanks:
        dsvariance_config["speakers"] = variance_embeds
    with open(f"{main_stuff}/dsvariance/dsconfig.yaml", "w") as config:
        yaml.dump(dsvariance_config, config)
else:
    print("\n")
    print("variance.onnx not found, skipping on making dsvariance folder...")

# !rm -rf {dsdict_path}
#im too lazy to write codes so ill just do this, itll only remove those folders if they're empty anyway
# !rm -d {main_stuff}/dsmain/embeds/* >/dev/null 2>&1
# !rm -d {main_stuff}/dsmain/embeds >/dev/null 2>&1

print("\n")
print("zipping up files...")
# !zip -q -9 -r {save_path}/{name}.zip {main_stuff}/*

print("\n")
print("done!")

print("\n")
print("You can download your model zip and use it in OpenUtau! If anything needed to be edit in the config then please do so")
# Out:
# /workspace/content
# copying files...
#
#
# writing character.txt...
#
#
# writing character.yaml...
#
#
# writing dsconfig.yaml for acoustic...
#
#
# writing dsdict.yaml...
#
#
# making dsdur directory and necessary files...
#
#
# making dspitch directory and necessary files...
#
#
# making dsvariance directory and necessary files...
#
#
# zipping up files...
#
#
# done!
#
#
# You can download your model zip and use it in OpenUtau! If anything needed to be edit in the config then please do so
